# %% [markdown]
# # How Search Works - Illustrative Example
#
# **Theme:** AI for Capacity Management

# %%
# %load_ext nb_black
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import seaborn as sns

from skill_match import SkillMatcher
from search import parse_demand, get_weight, _skill_names_to_ids
from retrieval import Retrieval, candidate_demand_similarity
from indexing import build_index

# %% [markdown]
# ### Step 0 - Indexing
# * Build an index of skills using the employee-skill pairs present in database.
# * Need to be built just once and updated when an employee is added or removed.
# * In production, build once and store on disk. Load from disk when required.

# %%
skill_tree = pd.read_csv("../data/skill_tree.csv", sep="\t")
skill_tree.head()
# Out:
#   Primary Unit  Sub Unit 1        Sub Unit 2  Sub Unit 3  \
# 0       Unit 1  Technology  Cloud Technology  Containers
# 1       Unit 1  Technology  Cloud Technology  Containers
# 2       Unit 1  Technology  Cloud Technology        PaaS
# 3       Unit 1  Technology  Cloud Technology        PaaS
# 4       Unit 1  Technology  Cloud Technology        PaaS
#
#                      Skill
# 0                   Docker
# 1               Kubernetes
# 2      Database management
# 3                   No SQL
# 4  Application Development

# %%
emp_skill_pairs = pd.read_csv("../data/emp_skills.csv", sep="\t")
emp_skill_pairs.head()
# Out:
#        emp_id  skill_id  skill_level
# 0  Employee 1        26            2
# 1  Employee 1        45            3
# 2  Employee 1        68            3
# 3  Employee 1        60            2
# 4  Employee 1        48            2

# %% [markdown]
# The following results show the list of employees who have a particular skill.

# %%
retrieval = Retrieval()
retrieval.index  # built when initialized
# Out:
# {26: {'Employee 1': 2},
#  45: {'Employee 1': 3, 'Employee 8': 3},
#  68: {'Employee 1': 3},
#  60: {'Employee 1': 2},
#  48: {'Employee 1': 2},
#  49: {'Employee 1': 3},
#  50: {'Employee 1': 3},
#  95: {'Employee 1': 3, 'Employee 2': 3, 'Employee 5': 2},
#  70: {'Employee 1': 2},
#  72: {'Employee 1': 3},
#  73: {'Employee 1': 3},
#  47: {'Employee 1': 3},
#  74: {'Employee 1': 3},
#  97: {'Employee 1': 3,
#   'Employee 2': 2,
#   'Employee 5': 3,
#   'Employee 7': 3,
#   'Employee 8': 4},
#  98: {'Employee 1': 3,
#   'Employee 3': 2,
#   'Employee 4': 2,
#   'Employee 5': 3,
#   'Employee 6': 3,
#   'Employee 9': 3,
#   'Employee 10': 3,
#   'Employee 11': 4,
#   'Employee 12': 2},
#  24: {'Employee 1': 1, 'Employee 5': 2, 'Employee 11': 2, 'Employee 13': 3},
#  25: {'Employee 1': 1, 'Employee 5': 3, 'Employee 11': 2},
#  51: {'Employee 2': 2},
#  96: {'Employee 2': 3},
#  61: {'Employee 2': 2},
#  87: {'Employee 3': 2},
#  88: {'Employee 3': 3},
#  91: {'Employee 3': 2},
#  81: {'Employee 3': 3, 'Employee 7': 2, 'Employee 12': 2},
#  83: {'Employee 3': 3, 'Employee 12': 2},
#  9: {'Employee 4': 4},
#  8: {'Employee 4': 4},
#  16: {'Employee 4': 4},
#  13: {'Employee 4': 4},
#  34: {'Employee 5': 3, 'Employee 6': 2},
#  30: {'Employee 5': 3},
#  31: {'Employee 5': 4},
#  22: {'Employee 5': 4, 'Employee 11': 3},
#  23: {'Employee 5': 3, 'Employee 11': 2},
#  5: {'Employee 5': 3, 'Employee 6': 4, 'Employee 13': 2},
#  94: {'Employee 5': 3, 'Employee 7': 3, 'Employee 8': 2},
#  11: {'Employee 6': 2, 'Employee 10': 2},
#  10: {'Employee 6': 3},
#  79: {'Employee 7': 3},
#  92: {'Employee 7': 3, 'Employee 12': 4},
#  76: {'Employee 7': 3, 'Employee 12': 3},
#  59: {'Employee 7': 1, 'Employee 8': 3},
#  46: {'Employee 8': 3},
#  55: {'Employee 8': 2},
#  66: {'Employee 8': 2},
#  18: {'Employee 9': 2},
#  19: {'Employee 9': 3, 'Employee 11': 3, 'Employee 13': 4},
#  20: {'Employee 9': 4},
#  14: {'Employee 10': 2},
#  15: {'Employee 10': 2},
#  7: {'Employee 11': 4, 'Employee 13': 3},
#  82: {'Employee 12': 3},
#  93: {'Employee 12': 4}}

# %% [markdown]
# ### Step 1 - Parse the input
#
# * Demand - skills, location, experience etc.
# * Search criteria
#
# Let's look at one example for demand.

# %%
demand_df = pd.read_csv("../data/demand.csv", sep="\t")
demand_df.head()
# Out:
#   Requestor Requestor Service Line Requestor Sub ServiceLine Requestor SMU  \
# 0     Req_1           ServiceLine3           SubserviceLine4          SMU2
# 1     Req_2           ServiceLine1           SubserviceLine1          SMU1
# 2     Req_3           ServiceLine2           SubserviceLine2          SMU3
# 3     Req_4           ServiceLine3           SubserviceLine1          SMU3
# 4     Req_5           ServiceLine3           SubserviceLine4          SMU2
#
#                       Job Title    Rank  No of Resources_required   Country  \
# 0        Financial Risk Analyst  Rank_3                         1     India
# 1   Data Visualisation Engineer  Rank_5                         1     India
# 2                   ML Engineer  Rank_3                         1     India
# 3  Account Reporting Specialist  Rank_4                         2    Poland
# 4              Business Analyst  Rank_4                         1  Germany
#
#    Location   Alternate Location        Technical Skill 1 Technical Skill 2  \
# 0  Bangalore                 NaN          Microsoft Excel    Microsoft Word
# 1      Kochi                 NaN             Dashboarding          Power BI
# 2  Bangalore                 NaN  Artificial Intelligence                ML
# 3     Warsaw                 NaN          Microsoft Excel               VBA
# 4       Koln                 NaN          Microsoft Visio  Microsoft Office
#
#   Technical Skill 3    Functional Skill 1    Functional Skill 2  \
# 0               NaN         Risk Analysis              Analysis
# 1               SQL  Requirement Analysis                   NaN
# 2            Python     Business Analysis  Requirement Analysis
# 3               NaN            Accounting        Internal Audit
# 4               NaN     Business Analysis              Taxation
#
#         Functional Skill 3  Process Skill 1     Process Skill 2  \
# 0               Accounting    Communication       Documentation
# 1                      NaN    Communication     Problem Solving
# 2           Data Modelling  Problem Solving  Analytical Ability
# 3                Reporting    Communication     Problem Solving
# 4  Business Case Modelling  Problem Solving       Communication
#
#       Process Skill 3  Min Experience
# 0          Team Skill               8
# 1          Team Skill               1
# 2       Communication               8
# 3  Analytical Ability               5
# 4       Documentation               5

# %%
demand = demand_df.iloc[2]
demand
# Out:
# Requestor                                      Req_3
# Requestor Service Line                  ServiceLine2
# Requestor Sub ServiceLine            SubserviceLine2
# Requestor SMU                                   SMU3
# Job Title                                ML Engineer
# Rank                                          Rank_3
# No of Resources_required                           1
# Country                                        India
# Location                                   Bangalore
# Alternate Location                               NaN
# Technical Skill 1            Artificial Intelligence
# Technical Skill 2                                 ML
# Technical Skill 3                             Python
# Functional Skill 1                 Business Analysis
# Functional Skill 2              Requirement Analysis
# Functional Skill 3                    Data Modelling
# Process Skill 1                      Problem Solving
# Process Skill 2                   Analytical Ability
# Process Skill 3                        Communication
# Min Experience                                     8
# Name: 2, dtype: object

# %% [markdown]
# #### Fuzzy string matching
#
# Now, we have to match the skills typed by the user, e.g. "machine learning" to the skills present in our database, "Machine Learning". Here comes the fuzzy logic that uses approximate string matching algorithms.
#
# #### Identifying related skills (a better way)
#
# Currently, there is no provision for identifying related skills. However, there are two ways I can think of to solve the problem.
# 1. Identifying commonly co-occuring skills from a database of employee-skill pairs. This can be done using apriori algorithm or FP-growth algorithm.
# 2. Computing semantically similar skills for a given skill using a large corpus of job descriptions. Computing semantic similarity in NLP is a solved problem. `gensim` is a great python library for this purpose.
#
# Both of these methods require appropriate datasets.

# %%
sm = SkillMatcher("../data/skill_tree.csv")

# %%
print(sm.match("artificial intelligence", unit="technical")[0])
# Out:
# Technology Emerging Trends Artificial Intelligence Deep Learning

# %%
print(sm.match("communication", unit="process")[0])
# Out:
# Process Soft Skills Effective Communication

# %% [markdown]
# Do the same for all skills and create a `demand` object.

# %%
demand = parse_demand(idx=2)  # parsing the same demand input as above
demand
# Out:
# Demand(skills=Skills(technical=[7, 23, 5], functional=[94, 94, 76], process=[102, 98, 101]), rank=3, location='Bangalore, India', experience=8, dept=Department(service_line='ServiceLine2', sub_service_line='SubserviceLine2', smu='SMU3'))

# %%
weight = get_weight(idx=0)  # search criteria
weight
# Out:
# criteria      Criteria1
# technical           0.1
# functional          0.3
# process             0.1
# experience          0.1
# rank                0.1
# location            0.3
# bench_age             0
# Name: 0, dtype: object

# %% [markdown]
# ### Step 2 - Retrieve the employees who have the skills
#
# Note there is an `OR` operator for retrieving by skills. For example, let's retrieve employees having a particular skill.

# %%
retrieval._get_candidates_for_skills([23])
# Out:
# {'Employee 5': 3, 'Employee 11': 2}

# %%
retrieval._get_candidates_for_skills([7])
# Out:
# {'Employee 11': 4, 'Employee 13': 3}

# %% [markdown]
# Look for all employees meeting the search criteria and return the union of all such results.

# %%
candidates = retrieval.get_candidates_df(demand.skills)
candidates
# Out:
#          emp_id  technical  functional  process  years_of_experience    rank  \
# 0   Employee 11        4.0         0.0      4.0                    2  Rank_5
# 1   Employee 13        3.0         0.0      0.0                    3  Rank_5
# 2    Employee 5        3.0         3.0      3.0                   15  Rank_2
# 3    Employee 6        4.0         0.0      3.0                   12  Rank_3
# 4    Employee 7        0.0         3.0      0.0                   13  Rank_3
# 5    Employee 8        0.0         2.0      0.0                   16  Rank_2
# 6   Employee 12        0.0         3.0      2.0                    8  Rank_4
# 7    Employee 1        0.0         0.0      3.0                   20  Rank_1
# 8    Employee 3        0.0         0.0      2.0                    9  Rank_4
# 9    Employee 4        0.0         0.0      2.0                    9  Rank_4
# 10   Employee 9        0.0         0.0      3.0                    7  Rank_4
# 11  Employee 10        0.0         0.0      3.0                    5  Rank_5
#
#     service_line sub_service_line   smu country        city  bench_age
# 0   ServiceLine1  SubServiceLine1  SMU2   India       Kochi          8
# 1   ServiceLine1  SubServiceLine1  SMU1   India       Kochi          3
# 2   ServiceLine1  SubServiceLine3  SMU1   India   Bangalore          5
# 3   ServiceLine1  SubServiceLine4  SMU1   India     Gurgaon          6
# 4   ServiceLine3  SubServiceLine2  SMU3   India     Chennai          3
# 5   ServiceLine1  SubServiceLine1  SMU3   India  Trivandrum          4
# 6   ServiceLine3  SubServiceLine2  SMU2   India   Bangalore          2
# 7   ServiceLine1  SubServiceLine1  SMU1   India     Gurgaon          4
# 8   ServiceLine3  SubServiceLine4  SMU1   India  Trivandrum          3
# 9   ServiceLine1  SubServiceLine2  SMU1   India       Kochi          6
# 10  ServiceLine1  SubServiceLine1  SMU1   India       Kochi          5
# 11  ServiceLine1  SubServiceLine4  SMU1   India   Bangalore          3

# %% [markdown]
# ### Step 3 - Ranking
#
# Now, `weight` comes into the picture and we must create a fitment score for all employees. The workhorse for this part is the similarity model, that's built using the weighted Euclidean distance metric.
#
# Euclidean distance between two vectors $A$ and $B$ is $$d(A, B) = \sqrt{\sum(A_i - B_i)^2}$$
#
# Weighted Euclidean distance is $$d(A, B) = \sqrt{\sum_i w_i \cdot (A_i - B_i)^2}$$
#
# To get similarity score $s$ from distance metric $d$, use $$s = \frac{1}{1+d}$$
#
# Note that similarity score $0 \le s \le 1$
#
# #### Normalize data
#
# However, for using the above similarity model, we need to normalize the data. Divide by the maximum value found in the dataset. For skills - technical, functional and process, max value is 4. For experience, rank and bench age, find the maximum value from the databse.

# %%
normalized_df = retrieval.normalize_data(candidates)
normalized_df
# Out:
#          emp_id  technical  functional  process  years_of_experience  rank  \
# 0   Employee 11       1.00        0.00     1.00                 0.10   1.0
# 1   Employee 13       0.75        0.00     0.00                 0.15   1.0
# 2    Employee 5       0.75        0.75     0.75                 0.75   0.4
# 3    Employee 6       1.00        0.00     0.75                 0.60   0.6
# 4    Employee 7       0.00        0.75     0.00                 0.65   0.6
# 5    Employee 8       0.00        0.50     0.00                 0.80   0.4
# 6   Employee 12       0.00        0.75     0.50                 0.40   0.8
# 7    Employee 1       0.00        0.00     0.75                 1.00   0.2
# 8    Employee 3       0.00        0.00     0.50                 0.45   0.8
# 9    Employee 4       0.00        0.00     0.50                 0.45   0.8
# 10   Employee 9       0.00        0.00     0.75                 0.35   0.8
# 11  Employee 10       0.00        0.00     0.75                 0.25   1.0
#
#     service_line sub_service_line   smu country        city  bench_age  \
# 0   ServiceLine1  SubServiceLine1  SMU2   India       Kochi      1.000
# 1   ServiceLine1  SubServiceLine1  SMU1   India       Kochi      0.375
# 2   ServiceLine1  SubServiceLine3  SMU1   India   Bangalore      0.625
# 3   ServiceLine1  SubServiceLine4  SMU1   India     Gurgaon      0.750
# 4   ServiceLine3  SubServiceLine2  SMU3   India     Chennai      0.375
# 5   ServiceLine1  SubServiceLine1  SMU3   India  Trivandrum      0.500
# 6   ServiceLine3  SubServiceLine2  SMU2   India   Bangalore      0.250
# 7   ServiceLine1  SubServiceLine1  SMU1   India     Gurgaon      0.500
# 8   ServiceLine3  SubServiceLine4  SMU1   India  Trivandrum      0.375
# 9   ServiceLine1  SubServiceLine2  SMU1   India       Kochi      0.750
# 10  ServiceLine1  SubServiceLine1  SMU1   India       Kochi      0.625
# 11  ServiceLine1  SubServiceLine4  SMU1   India   Bangalore      0.375
#
#              location
# 0        Kochi, India
# 1        Kochi, India
# 2    Bangalore, India
# 3      Gurgaon, India
# 4      Chennai, India
# 5   Trivandrum, India
# 6    Bangalore, India
# 7      Gurgaon, India
# 8   Trivandrum, India
# 9        Kochi, India
# 10       Kochi, India
# 11   Bangalore, India

# %% [markdown]
# All numerical values are now in the range of 0-1. Let's demonstrate the similarity function for `Employee 13`.

# %%
candidate_demand_similarity(normalized_df.iloc[6], demand, weight)
# Out:
# 0.7223436528299778

# %% [markdown]
# The only thing remaining is to find similarity score (fitment score) for all employees and view the results.
#
# #### Department similarity score
# We also create a department similarity score which is a simple function
# * similarity = 3 if both from same service_line+sub_service_line+smu
# * similarity = 2 if both from same service_line+sub_service_line
# * similarity = 1 if both from same service_line
# * similarity = 0 if both from different service_line
#
# When `sort_by_dept=True`, we sort by dept_similarity first, then fitment scores. What this means for the user: if preference is someone from the same department, show them first.

# %%
result = retrieval.get_results(demand, weight, sort_by_dept=False)

# %%
demand
# Out:
# Demand(skills=Skills(technical=[7, 23, 5], functional=[94, 94, 76], process=[102, 98, 101]), rank=3, location='Bangalore, India', experience=8, dept=Department(service_line='ServiceLine2', sub_service_line='SubserviceLine2', smu='SMU3'))

# %%
result
# Out:
#          emp_id  technical  functional  process  years_of_experience    rank  \
# 2    Employee 5        3.0         3.0      3.0                   15  Rank_2
# 6   Employee 12        0.0         3.0      2.0                    8  Rank_4
# 11  Employee 10        0.0         0.0      3.0                    5  Rank_5
# 4    Employee 7        0.0         3.0      0.0                   13  Rank_3
# 5    Employee 8        0.0         2.0      0.0                   16  Rank_2
# 3    Employee 6        4.0         0.0      3.0                   12  Rank_3
# 10   Employee 9        0.0         0.0      3.0                    7  Rank_4
# 1   Employee 13        3.0         0.0      0.0                    3  Rank_5
# 8    Employee 3        0.0         0.0      2.0                    9  Rank_4
# 9    Employee 4        0.0         0.0      2.0                    9  Rank_4
# 7    Employee 1        0.0         0.0      3.0                   20  Rank_1
# 0   Employee 11        4.0         0.0      4.0                    2  Rank_5
#
#     service_line sub_service_line   smu country        city  bench_age  \
# 2   ServiceLine1  SubServiceLine3  SMU1   India   Bangalore          5
# 6   ServiceLine3  SubServiceLine2  SMU2   India   Bangalore          2
# 11  ServiceLine1  SubServiceLine4  SMU1   India   Bangalore          3
# 4   ServiceLine3  SubServiceLine2  SMU3   India     Chennai          3
# 5   ServiceLine1  SubServiceLine1  SMU3   India  Trivandrum          4
# 3   ServiceLine1  SubServiceLine4  SMU1   India     Gurgaon          6
# 10  ServiceLine1  SubServiceLine1  SMU1   India       Kochi          5
# 1   ServiceLine1  SubServiceLine1  SMU1   India       Kochi          3
# 8   ServiceLine3  SubServiceLine4  SMU1   India  Trivandrum          3
# 9   ServiceLine1  SubServiceLine2  SMU1   India       Kochi          6
# 7   ServiceLine1  SubServiceLine1  SMU1   India     Gurgaon          4
# 0   ServiceLine1  SubServiceLine1  SMU2   India       Kochi          8
#
#      fitment  dept_similarity
# 2   0.821055                0
# 6   0.722344                0
# 11  0.605497                0
# 4   0.579855                0
# 5   0.564537                0
# 3   0.561424                0
# 10  0.542620                0
# 1   0.539513                0
# 8   0.539386                0
# 9   0.539386                0
# 7   0.534538                0
# 0   0.439608                0
